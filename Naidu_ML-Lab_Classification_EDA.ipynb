# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
os.chdir("/content/drive/MyDrive/Naidu")

# %%
df=pd.read_csv("apples_and_oranges.csv")

# %%
df.head()
# Out:
#    Weight  Size   Class
# 0      69  4.39  orange
# 1      69  4.21  orange
# 2      65  4.09  orange
# 3      72  5.85   apple
# 4      67  4.70  orange

# %%
df.shape
# Out:
# (40, 3)

# %%
df.describe()
# Out:
#           Weight       Size
# count  40.000000  40.000000
# mean   70.200000   4.922750
# std     3.039906   0.590063
# min    65.000000   4.010000
# 25%    68.000000   4.360000
# 50%    70.000000   4.930000
# 75%    73.000000   5.472500
# max    75.000000   5.850000

# %%
df.isnull().sum()
# Out:
# Weight    0
# Size      0
# Class     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Weight  40 non-null     int64
#  1   Size    40 non-null     float64
#  2   Class   40 non-null     object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.1+ KB

# %%
df1=df[df["Class"]=="orange"]

# %%
df2=df[df["Class"]=="apple"]

# %%
plt.scatter(df1["Weight"],df1["Size"])
plt.scatter(df2["Weight"],df2["Size"])
plt.show()
